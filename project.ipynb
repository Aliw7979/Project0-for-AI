# %%
import pandas as pd
print(pd.__version__)
df = pd.read_csv('bank_term_deposit.csv')
print(df.to_string())
# Out:
# 1.4.1
#        age            job   marital  education  balance housing loan  duration  campaign  pdays poutcome    y
# 0     30.0     unemployed   married    primary   1787.0      no   no      79.0         1     -1  unknown   no
# 1     33.0       services   married  secondary   4789.0     yes  yes       NaN         1    339  failure   no
# 2      NaN     management    single   tertiary    135.0     yes   no     185.0         1    330  failure   no
# 3     30.0     management   married   tertiary   1476.0     yes  yes     199.0         4     -1  unknown   no
# 4     59.0    blue-collar   married  secondary      NaN     yes   no     226.0         1     -1  unknown   no
# 5      NaN     management    single   tertiary    747.0     NaN   no     141.0         2    176  failure   no
# 6     36.0  self-employed   married   tertiary     37.0     yes   no     341.0         1    330    other   no
# ...

# %% [markdown]
# همانطورکه مشاهده می شود ما تمام اطلاعات داخل فایل سی اس وس را درون یک دیتا فریم ‌‌‌‌ذخیره کرده و آن را نمایش می دهیم

# %%
perc =[.25, .50, .75, .100]
desc = df.describe(percentiles = perc)
desc
# Out:
#                age       balance     duration     campaign        pdays
# count  3984.000000   4164.000000  4388.000000  4521.000000  4521.000000
# mean     41.617470   1136.750240   264.724020     2.793630    39.766645
# std      10.696378   2726.204918   261.057119     3.109807   100.121124
# min      19.000000  -3313.000000     4.000000     1.000000    -1.000000
# 10%      29.000000      2.000000    58.000000     1.000000    -1.000000
# 25%      32.000000     58.000000   104.000000     1.000000    -1.000000
# 50%      40.000000    316.000000   185.500000     2.000000    -1.000000
# 75%      49.000000    997.000000   331.000000     3.000000    -1.000000
# max      87.000000  71188.000000  3025.000000    50.000000   871.000000

# %%
df.tail()
# Out:
#        age            job  marital  education  balance housing loan  duration  \
# 4516  33.0       services  married  secondary   -333.0     yes   no     329.0
# 4517  57.0  self-employed  married   tertiary  -3313.0     yes  yes     153.0
# 4518  57.0     technician  married  secondary    295.0      no   no     151.0
# 4519  28.0    blue-collar  married  secondary   1137.0      no   no     129.0
# 4520  44.0   entrepreneur   single   tertiary   1136.0     yes  yes     345.0
#
#       campaign  pdays poutcome   y
# 4516         5     -1  unknown  no
# 4517         1     -1  unknown  no
# 4518        11     -1  unknown  no
# 4519         4    211    other  no
# 4520         2    249    other  no

# %%
df.head()
# Out:
#     age          job  marital  education  balance housing loan  duration  \
# 0  30.0   unemployed  married    primary   1787.0      no   no      79.0
# 1  33.0     services  married  secondary   4789.0     yes  yes       NaN
# 2   NaN   management   single   tertiary    135.0     yes   no     185.0
# 3  30.0   management  married   tertiary   1476.0     yes  yes     199.0
# 4  59.0  blue-collar  married  secondary      NaN     yes   no     226.0
#
#    campaign  pdays poutcome   y
# 0         1     -1  unknown  no
# 1         1    339  failure  no
# 2         1    330  failure  no
# 3         4     -1  unknown  no
# 4         1     -1  unknown  no

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4521 entries, 0 to 4520
# Data columns (total 12 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   age        3984 non-null   float64
#  1   job        4521 non-null   object
#  2   marital    4401 non-null   object
#  3   education  4521 non-null   object
#  4   balance    4164 non-null   float64
#  5   housing    4302 non-null   object
#  6   loan       4521 non-null   object
#  7   duration   4388 non-null   float64
#  8   campaign   4521 non-null   int64
#  9   pdays      4521 non-null   int64
#  10  poutcome   4521 non-null   object
#  11  y          4087 non-null   object
# dtypes: float64(3), int64(2), object(7)
# memory usage: 424.0+ KB

# %%
encodingDict = {
    'divorced' : 0,
    'single' : 1,
    'married' : 2, 
    }
df["marital"] = df["marital"].map(encodingDict)
df
# Out:
#        age            job  marital  education  balance housing loan  duration  \
# 0     30.0     unemployed      2.0    primary   1787.0      no   no      79.0
# 1     33.0       services      2.0  secondary   4789.0     yes  yes       NaN
# 2      NaN     management      1.0   tertiary    135.0     yes   no     185.0
# 3     30.0     management      2.0   tertiary   1476.0     yes  yes     199.0
# 4     59.0    blue-collar      2.0  secondary      NaN     yes   no     226.0
# ...    ...            ...      ...        ...      ...     ...  ...       ...
# 4516  33.0       services      2.0  secondary   -333.0     yes   no     329.0
# 4517  57.0  self-employed      2.0   tertiary  -3313.0     yes  yes     153.0
# 4518  57.0     technician      2.0  secondary    295.0      no   no     151.0
# 4519  28.0    blue-collar      2.0  secondary   1137.0      no   no     129.0
# 4520  44.0   entrepreneur      1.0   tertiary   1136.0     yes  yes     345.0
#
# ...

# %%
df.isna().sum()
# Out:
# age          537
# job            0
# marital      120
# education      0
# balance      357
# housing      219
# loan           0
# duration     133
# campaign       0
# pdays          0
# poutcome       0
# y            434
# dtype: int64

# %%
df = df.fillna(df.mean())
nan = df[df['y'].isnull()]
df =df[df['y'].notnull()]
print(df.to_string())
# Out:
# /tmp/ipykernel_26892/1777244014.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df = df.fillna(df.mean())
#            age            job   marital  education      balance housing loan    duration  campaign  pdays poutcome    y
# 0     30.00000     unemployed  2.000000    primary   1787.00000      no   no    79.00000         1     -1  unknown   no
# 1     33.00000       services  2.000000  secondary   4789.00000     yes  yes   264.72402         1    339  failure   no
# 2     41.61747     management  1.000000   tertiary    135.00000     yes   no   185.00000         1    330  failure   no
# 3     30.00000     management  2.000000   tertiary   1476.00000     yes  yes   199.00000         4     -1  unknown   no
# ...

# %%
print(nan.to_string())
# Out:
#            age            job   marital  education      balance housing loan    duration  campaign  pdays poutcome    y
# 34    49.00000     technician  2.000000   tertiary   1235.00000      no   no   354.00000         3     -1  unknown  NaN
# 38    33.00000     management  2.000000  secondary   3935.00000     yes   no   765.00000         1    342  failure  NaN
# 54    41.61747    blue-collar  2.000000  secondary   2231.00000     yes   no   272.00000         3     -1  unknown  NaN
# 65    51.00000    blue-collar  0.000000  secondary     23.00000     yes   no   134.00000         1    170  failure  NaN
# 89    41.61747    blue-collar  2.000000  secondary   1831.00000     yes   no   203.00000         2     -1  unknown  NaN
# 90    39.00000    blue-collar  2.000000    primary    111.00000      no   no   201.00000         2     -1  unknown  NaN
# 94    57.00000    blue-collar  2.000000  secondary   1493.00000      no   no   231.00000         5     -1  unknown  NaN
# ...

# %%
df['housing'].value_counts(dropna=True)
# Out:
# yes    2188
# no     1698
# Name: housing, dtype: int64

# %%
df['y'].value_counts()
# Out:
# no     3623
# yes     464
# Name: y, dtype: int64

# %%
(df.loc[(df['age'] > 35) & (df['marital'] == 1) & (df['poutcome'] == "success") ]).value_counts()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File ~/.local/lib/python3.8/site-packages/pandas/core/ops/array_ops.py:301, in na_logical_op(x, y, op)
#     <a href='file:///~/.local/lib/python3.8/site-packages/pandas/core/ops/array_ops.py?line=291'>292</a> try:
#     <a href='file:///~/.local/lib/python3.8/site-packages/pandas/core/ops/array_ops.py?line=292'>293</a>     # For exposition, write:
#     <a href='file:///~/.local/lib/python3.8/site-packages/pandas/core/ops/array_ops.py?line=293'>294</a>     #  yarr = isinstance(y, np.ndarray)
#    (...)
#     <a href='file:///~/.local/lib/python3.8/site-packages/pandas/core/ops/array_ops.py?line=298'>299</a>     # Then Cases where this goes through without raising include:
#     <a href='file:///~/.local/lib/python3.8/site-packages/pandas/core/ops/array_ops.py?line=299'>300</a>     #  (xint or xbool) and (yint or bool)
# ...
